# %%
import numpy as np

# %%
# %mkdir 'Textbook Graphs'

# %%
def f(x):
    return np.exp(x) - 3*x**2

# %%
x = np.linspace(-1,1.5,100)
xx = np.array([-1,0,0.5,1])

# %%
plt.figure(figsize = (10,10))
plt.plot(x,f(x))
plt.ylabel('$f(x) = e^{x} - 3x^{2}$', size = 18)
plt.plot(xx, f(xx), 'd', markersize = 10)
plt.xlabel('$x$', size = 18)
plt.hlines(0, -1, 1.5, linestyles= 'dashed')
plt.annotate('B', xy = (.9,0), xytext = (.9,-.5), 
             arrowprops = dict(width = 0.1, facecolor = 'black', shrink = 0.07))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.9,-0.5,'B')

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
x = np.array([1,2,3,4,5])

# %%
type(x)
# Out:
# numpy.ndarray

# %%
# Out:
# 'things'

# %%
z =  {'Name': ['Cody', 'Kaitie'], 'Age': [25, 23]}

# %%
plt.figure(1)
plt.plot(x,y,'.')
plt.figure(2)
plt.plot(y,x)

# %% [markdown]
# # This is a title
# ## This is not
# ### things and stuff
# normal words and stuff

# %%
cd ~
# Out:
# /home/cody

# %%
# %%writefile hello_world.py
def hello():
    return print('Hello World! :)')
hello()
# Out:
# Overwriting hello_world.py

# %%
# %load BC_caseI.py
def BC_caseI(omega):
    """
    Finds the value of w_1(x) at the end point. x = L = 1 (m)
    
    """
    from caseI import caseI
    from rk2 import rk2
    L = 2.
    
    w0 = [0.0, 1.0, omega]
    w = rk2(w0, 0.0, 0.001,1, caseI)
    
    return w[-1, 0]

# %% [markdown]
# This is a fucntion $f(x)$
