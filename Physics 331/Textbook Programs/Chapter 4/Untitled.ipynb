# %% [markdown]
# # Chapter 4 Stuff

# %%
# %pwd
# Out:
# '/home/cody/Physics 331/Textbook Programs/Chapter 4'

# %%
# %ls
# Out:
# Error vs Run Time.png  READ ME.txt  sky_diver.py
# euler_1d.py            rk2_1d.py    Untitled.ipynb

# %%
# %run euler_1d.py
# %run sky_diver.py
# %run rk2_1d.py

# %%
t, y = euler_1d(100, 0, 30, 0.1, sky_diver)
t2, y2 = euler_1d(100, 0, 30, 3, sky_diver)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(t,y, t2, y2)
plt.ylim(-520,520)
# Out:
# (-520, 520)

# %%
def exercise(y,t):
    lam = 10
    return lam*y

# %%
t, y = euler_1d(1, 0, 1+0.25, .25, exercise)
t2, y2 = euler_1d(1, 0, 1.1, 0.1, exercise)

t3, y3 = rk2_1d(1, 0, 1+0.25, .25, exercise)
t4, y4 = rk2_1d(1, 0, 1, 0.01, exercise)

time = np.linspace(0,1,100)
y_an = np.exp(10*time)

# %%
plt.figure(figsize = (10,20))
plt.plot(t,y, 'x-', label = 'Euler 1 step')
plt.plot(t2,y2, 'x-', label = 'Euler 2 steps')
plt.plot(t3,y3, 'x-', label = 'RK 1 Step')
plt.plot(t4,y4, 'x-', label = 'RK 2 Steps')
plt.plot(time, y_an, label = 'Analytic Solution')
plt.legend()
plt.show()

# %%
y = None

# %%
def foo():
    print(y)

# %%
foo()
# Out:
# None

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_1',
#  '_10',
#  '_12',
#  '_16',
#  '_17',
#  '_20',
#  '_23',
#  '_25',
#  '_26',
#  '_5',
#  '_6',
#  '_61',
#  '_7',
#  '_8',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__nonzero__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i4',
#  '_i40',
#  '_i41',
#  '_i42',
#  '_i43',
#  '_i44',
#  '_i45',
#  '_i46',
#  '_i47',
#  '_i48',
#  '_i49',
#  '_i5',
#  '_i50',
#  '_i51',
#  '_i52',
#  '_i53',
#  '_i54',
#  '_i55',
#  '_i56',
#  '_i57',
#  '_i58',
#  '_i59',
#  '_i6',
#  '_i60',
#  '_i61',
#  '_i62',
#  '_i63',
# ...

# %%
# Out:
# ['',
#  "get_ipython().run_line_magic('pwd', '')",
#  "get_ipython().run_line_magic('run', 'euler_1d.py')\nget_ipython().run_line_magic('run', 'sky_diver.py')",
#  't, y = euler_1d(100, 0, 30, 0.1, sky_diver)\nt2, y2 = euler_1d(100, 0, 30, 4, sky_diver)',
#  'import matplotlib.pyplot as plt',
#  'plt.plot(t,y, t2, y2)',
#  'plt.plot(t,y, t2, y2)\nplt.ylim(120,-10)',
#  'plt.plot(t,y, t2, y2)\nplt.ylim(-10,120)',
#  'plt.plot(t,y, t2, y2)\nplt.ylim(-120,120)',
#  'plt.plot(t,y, t2, y2)\nplt.ylim(-120,220)',
#  'plt.plot(t,y, t2, y2)\nplt.ylim(-520,520)',
#  't, y = euler_1d(100, 0, 30, 0.1, sky_diver)\nt2, y2 = euler_1d(100, 0, 30, 3, sky_diver)',
#  'plt.plot(t,y, t2, y2)\nplt.ylim(-520,520)',
#  "get_ipython().run_line_magic('run', 'euler_1d.py')\nget_ipython().run_line_magic('run', 'sky_diver.py')\nget_ipython().run_line_magic('run', 'rk2_1d.py')",
#  'def exercise(y,t):\n    lam = 2\n    return lam*y',
#  't, y = euler_1d(1, 0, 1, 1, exercise)',
#  'plt.plot(t,y)',
#  't',
# ...

# %%
x = 4

# %%
# Out:
#   File "<ipython-input-74-646e3a5bea61>", line 1
#     4 = x
#          ^
# SyntaxError: can't assign to literal
