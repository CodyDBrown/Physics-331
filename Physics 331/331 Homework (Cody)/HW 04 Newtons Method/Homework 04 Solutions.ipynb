# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
z = np.linspace(-5*np.pi/2, 5*np.pi/2, 1000)
plt.plot(z, np.tan(z),'x')
plt.plot(z,np.sqrt((8/z)**2 -1))
plt.ylim(-100,100)
# Out:
# (-100, 100)

# %%
-np.sin(np.pi/4)
# Out:
# -0.7071067811865475

# %%
-np.sin(-np.pi/4)
# Out:
# 0.7071067811865475
